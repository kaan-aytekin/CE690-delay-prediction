# %%
import os
import pandas as pd
import pprint
from IPython.display import display, Markdown

# %%
def printmd(string, color=None):
    colorstr = "<span style='color:{}'>{}</span>".format(color, string)
    display(Markdown(colorstr))

# %%
ROOT_DIRECTORY = "/home/kaan.aytekin/Thesis"
#ROOT_DIRECTORY = "/Users/kaan.aytekin/Desktop/Kaan/Thesis"

# %% [markdown]
# ## Load Data

# %%
mi_feat_data_path = os.path.join(ROOT_DIRECTORY,"data/thesis_data/mutual_information_feature_orders.csv")
corr_feat_data_path = os.path.join(ROOT_DIRECTORY,"data/thesis_data/correlation_feature_orders.csv")
rf_feat_data_path = os.path.join(ROOT_DIRECTORY,"data/thesis_data/random_forest_feature_orders.csv")
rrf_feat_data_path = os.path.join(ROOT_DIRECTORY,"data/thesis_data/regularized_random_forest_feature_orders.csv")


mutual_information_feature_importance_df = pd.read_csv(mi_feat_data_path)
correlation_feature_importance_df = pd.read_csv(corr_feat_data_path)
random_forest_feature_importance_df = pd.read_csv(rf_feat_data_path)
regularized_random_forest_feature_importance_df = pd.read_csv(rrf_feat_data_path)

# %%
mutual_information_feature_importance_df["source"] = "mutual_importance"
correlation_feature_importance_df["source"] = "correlation"
random_forest_feature_importance_df["source"] = "rf_feature_importance"
regularized_random_forest_feature_importance_df["source"] = "rrf_feature_importance"

# %%
printmd("**Mutual Information**",color="green")
display(mutual_information_feature_importance_df.head(),mutual_information_feature_importance_df.tail())
printmd("**Correlation**",color="green")
display(correlation_feature_importance_df.head(),correlation_feature_importance_df.tail())
printmd("**Random Forest**",color="green")
display(random_forest_feature_importance_df.head(),random_forest_feature_importance_df.tail())
printmd("**Regularized Random Forest**",color="green")
display(regularized_random_forest_feature_importance_df.head(),regularized_random_forest_feature_importance_df.tail())
# Out:
# <span style='color:green'>**Mutual Information**</span>
#                         feature     value  order             source
# 0       section_travel_time_sec  0.659285      1  mutual_importance
# 1                delay_time_sec  0.659148      2  mutual_importance
# 2                avg_speed_kmph  0.657341      3  mutual_importance
# 3           avg_speed_kmph_lag1  0.455751      4  mutual_importance
# 4  section_travel_time_sec_lag1  0.455436      5  mutual_importance
#                            feature     value  order             source
# 163  next_detector_flow_vehph_lag6  0.046786    164  mutual_importance
# 164  next_detector_flow_vehph_lag9  0.043240    165  mutual_importance
# 165           distance_to_accident  0.033427    166  mutual_importance
# 166    time_after_accident_started  0.011453    167  mutual_importance
# 167          is_accident_timestamp  0.005970    168  mutual_importance
# <span style='color:green'>**Correlation**</span>
#                         feature     value  order       source
# 0                delay_time_sec  0.831758      1  correlation
# 1       section_travel_time_sec  0.831758      2  correlation
# 2           delay_time_sec_lag1  0.723303      3  correlation
# 3  section_travel_time_sec_lag1  0.723303      4  correlation
# 4  section_travel_time_sec_lag3  0.687927      5  correlation
#                             feature     value  order       source
# 163   next_detector_flow_vehph_lag9  0.065011    164  correlation
# 164   next_detector_flow_vehph_lag7  0.064051    165  correlation
# 165  next_detector_flow_vehph_lag10  0.061084    166  correlation
# 166           is_accident_timestamp  0.051727    167  correlation
# 167            distance_to_accident -0.051723    168  correlation
# <span style='color:green'>**Random Forest**</span>
#                         feature         value  order                 source
# 0       section_travel_time_sec  7.124881e+06      1  rf_feature_importance
# 1                delay_time_sec  6.708992e+06      2  rf_feature_importance
# 2                avg_speed_kmph  4.010971e+06      3  rf_feature_importance
# 3           delay_time_sec_lag1  1.822658e+06      4  rf_feature_importance
# 4  section_travel_time_sec_lag1  1.624110e+06      5  rf_feature_importance
#                                         feature        value  order  \
# 163                             flow_vehph_lag6  9142.837747    164
# 164                             flow_vehph_lag9  8622.276305    165
# 165  prev_detector_section_travel_time_sec_lag6  8202.162755    166
# 166           prev_detector_delay_time_sec_lag6  8125.234508    167
# 167                       is_accident_timestamp  2495.723727    168
#
#                     source
# 163  rf_feature_importance
# 164  rf_feature_importance
# 165  rf_feature_importance
# 166  rf_feature_importance
# 167  rf_feature_importance
# <span style='color:green'>**Regularized Random Forest**</span>
#                         feature         value  order                  source
# 0                delay_time_sec  7.398173e+06      1  rrf_feature_importance
# 1       section_travel_time_sec  6.533061e+06      2  rrf_feature_importance
# 2                avg_speed_kmph  4.033253e+06      3  rrf_feature_importance
# 3  section_travel_time_sec_lag1  1.840471e+06      4  rrf_feature_importance
# 4           delay_time_sec_lag1  1.372206e+06      5  rrf_feature_importance
#                                         feature        value  order  \
# 163           prev_detector_avg_speed_kmph_lag6  9514.557003    164
# 164                             flow_vehph_lag7  9210.548460    165
# 165  prev_detector_section_travel_time_sec_lag5  7594.364747    166
# 166  prev_detector_section_travel_time_sec_lag7  5404.750878    167
# 167                       is_accident_timestamp   953.132423    168
#
#                      source
# 163  rrf_feature_importance
# 164  rrf_feature_importance
# 165  rrf_feature_importance
# 166  rrf_feature_importance
# 167  rrf_feature_importance

# %%
feature_importance_df = mutual_information_feature_importance_df.append(correlation_feature_importance_df).append(random_forest_feature_importance_df).append(regularized_random_forest_feature_importance_df).reset_index(drop=True)

# %%
feature_importance_order_df = feature_importance_df.pivot(index="feature",columns="source",values="order").sort_values(by=["mutual_importance","rrf_feature_importance","rf_feature_importance","correlation"])

# %%
feature_importance_order_df = feature_importance_order_df.reset_index()#.drop("source")
del feature_importance_order_df.columns.name

# %% [markdown]
# ## Serialize Data

# %%
feature_importance_order_data_path = os.path.join(ROOT_DIRECTORY,"data/thesis_data/feature_importance_orders.csv")
try:
    feature_importance_order_df = pd.read_csv(feature_importance_order_data_path)
except:
    feature_importance_order_df.to_csv(feature_importance_order_data_path,index=False)

# %%
top_features_df = feature_importance_order_df[
    (feature_importance_order_df.correlation < 30)
    | (feature_importance_order_df.mutual_importance < 30)
    | (feature_importance_order_df.rf_feature_importance < 30)
    | (feature_importance_order_df.rrf_feature_importance < 30)
].reset_index(drop=True)

# %%
display(top_features_df)
# Out:
#                                        feature  correlation  \
# 0                      section_travel_time_sec            2
# 1                               delay_time_sec            1
# 2                               avg_speed_kmph           46
# 3                          avg_speed_kmph_lag1           53
# 4                 section_travel_time_sec_lag1            4
# 5                          delay_time_sec_lag1            3
# 6            prev_detector_avg_speed_kmph_lag3           90
# 7   prev_detector_section_travel_time_sec_lag3           93
# 8            prev_detector_delay_time_sec_lag3           94
# 9                          avg_speed_kmph_lag2           56
# 10           prev_detector_avg_speed_kmph_lag4           95
# 11                              density_vehpkm           21
# 12           prev_detector_delay_time_sec_lag2           78
# 13  prev_detector_section_travel_time_sec_lag2           77
# 14                section_travel_time_sec_lag2           12
# 15                         delay_time_sec_lag2           11
# 16           prev_detector_avg_speed_kmph_lag2           87
# 17           prev_detector_delay_time_sec_lag4           99
# 18  prev_detector_section_travel_time_sec_lag4           98
# 19                section_travel_time_sec_lag3            5
# 20                         delay_time_sec_lag3            6
# 21                         avg_speed_kmph_lag3           58
# 22           prev_detector_avg_speed_kmph_lag1           88
# 23           prev_detector_delay_time_sec_lag1           68
# 24  prev_detector_section_travel_time_sec_lag1           67
# 25                         avg_speed_kmph_lag4           60
# 26                         density_vehpkm_lag1           26
# 27           prev_detector_avg_speed_kmph_lag5          106
# 28           prev_detector_density_vehpkm_lag3           89
# 29                         delay_time_sec_lag4            8
# 30                section_travel_time_sec_lag4            7
# 31                         delay_time_sec_lag5            9
# 32                section_travel_time_sec_lag5           10
# 33                         delay_time_sec_lag6           15
# 34                         density_vehpkm_lag2           27
# 35                section_travel_time_sec_lag6           16
# 36                section_travel_time_sec_lag7           18
# 37                         delay_time_sec_lag7           17
# 38                section_travel_time_sec_lag8           25
# 39                         delay_time_sec_lag8           24
# 40                         avg_speed_kmph_lag8           70
# 41           next_detector_avg_speed_kmph_lag1          108
# 42  next_detector_section_travel_time_sec_lag1           50
# 43           next_detector_avg_speed_kmph_lag5          101
# 44  next_detector_section_travel_time_sec_lag4           28
# 45           next_detector_delay_time_sec_lag4           29
# 46  next_detector_section_travel_time_sec_lag6           14
# 47           next_detector_delay_time_sec_lag6           13
# 48  next_detector_section_travel_time_sec_lag5           19
# 49           next_detector_delay_time_sec_lag5           20
# 50           next_detector_avg_speed_kmph_lag6          100
# 51  next_detector_section_travel_time_sec_lag7           23
# 52           next_detector_delay_time_sec_lag7           22
# 53           next_detector_density_vehpkm_lag5           65
# 54           next_detector_density_vehpkm_lag6           69
# 55           next_detector_density_vehpkm_lag8           74
# 56               next_detector_flow_vehph_lag4          160
# 57               next_detector_flow_vehph_lag8          163
#
#     mutual_importance  rf_feature_importance  rrf_feature_importance
# 0                   1                      1                       2
# 1                   2                      2                       1
# 2                   3                      3                       3
# 3                   4                      6                       6
# 4                   5                      5                       4
# 5                   6                      4                       5
# 6                   7                     71                      74
# 7                   8                     62                      65
# 8                   9                     63                      69
# 9                  10                     18                      20
# 10                 11                    107                      99
# 11                 12                     10                      11
# 12                 13                     72                      50
# 13                 14                     35                      47
# 14                 15                     11                      12
# 15                 16                     12                       9
# 16                 17                     41                      46
# 17                 18                    110                     114
# 18                 19                    124                     149
# 19                 20                     27                      17
# 20                 21                     17                      18
# 21                 22                     25                      25
# 22                 23                    111                     117
# 23                 24                     88                     145
# 24                 25                    109                     147
# 25                 26                     47                     100
# 26                 27                     22                      16
# 27                 28                     82                     120
# 28                 29                     74                      84
# 29                 33                     58                      55
# 30                 36                     24                      54
# 31                 38                     80                      73
# 32                 39                     83                      82
# 33                 44                     96                      96
# 34                 45                     16                      19
# 35                 46                    119                     121
# 36                 51                     76                      91
# 37                 52                     52                      63
# 38                 57                     28                      22
# 39                 58                     20                      23
# 40                 59                     21                      24
# 41                 69                     32                      29
# 42                 75                     29                      31
# 43                 85                     13                      14
# 44                 93                     48                      51
# 45                 97                     40                      41
# 46                 99                      8                       8
# 47                100                      7                       7
# 48                105                     14                      13
# 49                106                     15                      15
# 50                107                      9                      10
# 51                112                    117                     101
# 52                113                    121                     127
# 53                117                     23                      26
# 54                119                     30                      28
# 55                124                     39                      27
# 56                157                     19                      21
# 57                159                     26                      32

# %%
top_features_data_path = os.path.join(ROOT_DIRECTORY,"data/thesis_data/top_features.txt")
top_features_df.to_csv(top_features_data_path,index=False)
