# %%
from sklearn.feature_selection import mutual_info_regression
import os
import pandas as pd
import numpy as np
import pprint
import seaborn as sns
from matplotlib import pyplot as plt

# %%
ROOT_DIRECTORY = "/home/kaan.aytekin/Thesis"
#ROOT_DIRECTORY = "/Users/kaan.aytekin/Desktop/Kaan/Thesis"

# %% [markdown]
# ## Data Loading

# %%
feature_list_path = os.path.join(ROOT_DIRECTORY,f"data/thesis_data/feature_names_list.txt")
with open(feature_list_path,"r") as reader:
    feature_columns = reader.read()
    feature_columns = feature_columns.split("\n")

# %%
x_train = pd.read_csv(os.path.join(ROOT_DIRECTORY,"data/thesis_data/x_train.csv"))[feature_columns]
y_train = pd.read_csv(os.path.join(ROOT_DIRECTORY,"data/thesis_data/y_train.csv")).target_delay_time.ravel()

df_train = x_train.copy()
df_train["target"] = y_train

x_test = pd.read_csv(os.path.join(ROOT_DIRECTORY,"data/thesis_data/x_test.csv"))[feature_columns]
y_test = pd.read_csv(os.path.join(ROOT_DIRECTORY,"data/thesis_data/y_test.csv")).target_delay_time.ravel()

# %%
# Label discrete feature(s)
#feature_columns = list(x_train.columns)
discrete_feature_index = feature_columns.get_loc("is_accident_timestamp")
discrete_feature_index_array = np.zeros(len(feature_columns))
discrete_feature_index_array[discrete_feature_index] = 1
discrete_feature_index_array = discrete_feature_index_array.astype(bool)

# %%
x_train.shape
# Out:
# (474807, 168)

# %% [markdown]
# ## Data Sampling

# %%
seed = 500
x_train_sample = x_train.sample(n=20_000,random_state=seed)
y_train_sample = y_train[x_train_sample.index]

# %% [markdown]
# ## Calculate Mutual Information

# %%
# Computationally expensive
feature_mutual_informations = mutual_info_regression(x_train_sample,y_train_sample,discrete_features=discrete_feature_index_array)

# %%
mutual_information_descending_importance_index = np.argsort(feature_mutual_informations)[::-1]
labeled_sorted_feature_mutual_informations = list(zip(feature_columns[mutual_information_descending_importance_index],feature_mutual_informations[mutual_information_descending_importance_index]))

# %%
pprint.pprint(labeled_sorted_feature_mutual_informations)
# Out:
# [('section_travel_time_sec', 0.6592846285418261),
#  ('delay_time_sec', 0.6591475516718184),
#  ('avg_speed_kmph', 0.6573405685591958),
#  ('avg_speed_kmph_lag1', 0.45575133160180314),
#  ('section_travel_time_sec_lag1', 0.45543609123517026),
#  ('delay_time_sec_lag1', 0.4550983482140314),
#  ('prev_detector_avg_speed_kmph_lag3', 0.38692412018222555),
#  ('prev_detector_section_travel_time_sec_lag3', 0.380536681409823),
#  ('prev_detector_delay_time_sec_lag3', 0.3797768915581443),
#  ('avg_speed_kmph_lag2', 0.36880068111145103),
#  ('prev_detector_avg_speed_kmph_lag4', 0.3636199987887849),
#  ('density_vehpkm', 0.36313145449743267),
#  ('prev_detector_delay_time_sec_lag2', 0.3581387307647548),
#  ('prev_detector_section_travel_time_sec_lag2', 0.3579961577779347),
#  ('section_travel_time_sec_lag2', 0.3547419391830644),
#  ('delay_time_sec_lag2', 0.3542522726229045),
#  ('prev_detector_avg_speed_kmph_lag2', 0.3518340870223371),
#  ('prev_detector_delay_time_sec_lag4', 0.3502123095668104),
#  ('prev_detector_section_travel_time_sec_lag4', 0.3495372016528506),
#  ('section_travel_time_sec_lag3', 0.3128826260473936),
#  ('delay_time_sec_lag3', 0.312667518601522),
#  ('avg_speed_kmph_lag3', 0.31114344622165824),
#  ('prev_detector_avg_speed_kmph_lag1', 0.30947777996983117),
#  ('prev_detector_delay_time_sec_lag1', 0.3028832157096968),
#  ('prev_detector_section_travel_time_sec_lag1', 0.30196830136266506),
#  ('avg_speed_kmph_lag4', 0.2889366945850522),
#  ('density_vehpkm_lag1', 0.2888624400229931),
#  ('prev_detector_avg_speed_kmph_lag5', 0.281487996913687),
#  ('prev_detector_density_vehpkm_lag3', 0.2739783688817843),
#  ('prev_detector_avg_speed_kmph', 0.2736188998466398),
#  ('prev_detector_delay_time_sec_lag5', 0.2713943248454358),
#  ('prev_detector_section_travel_time_sec_lag5', 0.27109973290123257),
#  ('delay_time_sec_lag4', 0.26804973556758416),
#  ('prev_detector_section_travel_time_sec', 0.26798763554501903),
#  ('prev_detector_delay_time_sec', 0.2679682498751861),
#  ('section_travel_time_sec_lag4', 0.2678470292346926),
#  ('prev_detector_density_vehpkm_lag4', 0.2647764163017472),
#  ('delay_time_sec_lag5', 0.26445910735101563),
#  ('section_travel_time_sec_lag5', 0.26433329462339916),
#  ('avg_speed_kmph_lag5', 0.2571135510804039),
#  ('prev_detector_avg_speed_kmph_lag6', 0.23833382133268177),
#  ('prev_detector_density_vehpkm_lag2', 0.2353499467097846),
#  ('avg_speed_kmph_lag6', 0.23498712320961257),
#  ('delay_time_sec_lag6', 0.2337797595719442),
#  ('density_vehpkm_lag2', 0.23337122351086137),
#  ('section_travel_time_sec_lag6', 0.23307819777792993),
#  ('prev_detector_delay_time_sec_lag6', 0.2309767583000948),
#  ('prev_detector_section_travel_time_sec_lag6', 0.23004880588261578),
#  ('density_vehpkm_lag3', 0.2217247648839944),
#  ('avg_speed_kmph_lag7', 0.21950515586933772),
#  ('section_travel_time_sec_lag7', 0.21168416103057286),
#  ('delay_time_sec_lag7', 0.21166984612751616),
#  ('prev_detector_density_vehpkm_lag5', 0.2082824941622512),
#  ('avg_speed_kmph_lag9', 0.20541046705573685),
#  ('density_vehpkm_lag4', 0.20500510127660831),
#  ('next_detector_avg_speed_kmph', 0.2044960095348376),
#  ('section_travel_time_sec_lag8', 0.20193913274137198),
#  ('delay_time_sec_lag8', 0.20182676593472326),
#  ('avg_speed_kmph_lag8', 0.20019206915963483),
#  ('prev_detector_avg_speed_kmph_lag7', 0.19665087685422744),
#  ('prev_detector_delay_time_sec_lag7', 0.19401964286301787),
#  ('density_vehpkm_lag5', 0.19361115157858944),
#  ('prev_detector_section_travel_time_sec_lag7', 0.19340216599572901),
#  ('next_detector_delay_time_sec', 0.19263767804916654),
#  ('next_detector_section_travel_time_sec', 0.19206932926112597),
#  ('prev_detector_avg_speed_kmph_lag8', 0.1912505299044156),
#  ('delay_time_sec_lag9', 0.19098377698655877),
#  ('section_travel_time_sec_lag9', 0.19084155084534604),
#  ('next_detector_avg_speed_kmph_lag1', 0.1907465628712659),
#  ('prev_detector_delay_time_sec_lag8', 0.19051122651891816),
#  ('prev_detector_section_travel_time_sec_lag8', 0.19033324699413523),
#  ('prev_detector_density_vehpkm_lag1', 0.1883877303136332),
#  ('section_travel_time_sec_lag10', 0.17947061249642537),
#  ('delay_time_sec_lag10', 0.1793420386405078),
#  ('next_detector_section_travel_time_sec_lag1', 0.17904006418303897),
#  ('next_detector_delay_time_sec_lag1', 0.1787575602001068),
#  ('avg_speed_kmph_lag10', 0.1787122197264983),
#  ('prev_detector_density_vehpkm_lag6', 0.17286773816777323),
#  ('density_vehpkm_lag6', 0.1725336572845615),
#  ('next_detector_avg_speed_kmph_lag3', 0.1708141193072823),
#  ('prev_detector_avg_speed_kmph_lag9', 0.17079028853887923),
#  ('next_detector_avg_speed_kmph_lag2', 0.16956620351915763),
#  ('next_detector_delay_time_sec_lag2', 0.1694560965561891),
#  ('next_detector_section_travel_time_sec_lag2', 0.16924007386524842),
#  ('next_detector_avg_speed_kmph_lag5', 0.16788487637980598),
#  ('prev_detector_delay_time_sec_lag9', 0.1677455366321503),
#  ('prev_detector_section_travel_time_sec_lag9', 0.16716621689018396),
#  ('density_vehpkm_lag7', 0.1650483800036877),
#  ('next_detector_section_travel_time_sec_lag3', 0.16334735865257421),
#  ('next_detector_delay_time_sec_lag3', 0.1626793685106538),
#  ('next_detector_avg_speed_kmph_lag4', 0.16089152829708642),
#  ('prev_detector_section_travel_time_sec_lag10', 0.1606745829560703),
#  ('next_detector_section_travel_time_sec_lag4', 0.16059604728812626),
#  ('prev_detector_avg_speed_kmph_lag10', 0.16036882839886513),
#  ('prev_detector_delay_time_sec_lag10', 0.16033526556778366),
#  ('flow_vehph', 0.16027079335580519),
#  ('next_detector_delay_time_sec_lag4', 0.16026122750299177),
#  ('next_detector_density_vehpkm', 0.15972487688127046),
#  ('next_detector_section_travel_time_sec_lag6', 0.15923965819694885),
#  ('next_detector_delay_time_sec_lag6', 0.1585285566461696),
#  ('prev_detector_flow_vehph_lag4', 0.15763889448023383),
#  ('prev_detector_flow_vehph_lag3', 0.15688508790600464),
#  ('density_vehpkm_lag8', 0.15667106432490918),
#  ('prev_detector_density_vehpkm', 0.15618770863280496),
#  ('next_detector_section_travel_time_sec_lag5', 0.1544423668712369),
#  ('next_detector_delay_time_sec_lag5', 0.15413238178838373),
#  ('next_detector_avg_speed_kmph_lag6', 0.15402027335777202),
#  ('next_detector_density_vehpkm_lag1', 0.14788299952110062),
#  ('density_vehpkm_lag9', 0.14741357194349103),
#  ('next_detector_density_vehpkm_lag4', 0.1468562798738784),
#  ('next_detector_avg_speed_kmph_lag9', 0.14598597601387464),
#  ('next_detector_section_travel_time_sec_lag7', 0.14320970185677684),
#  ('next_detector_delay_time_sec_lag7', 0.1427224372560829),
#  ('next_detector_density_vehpkm_lag3', 0.14258918489483108),
#  ('next_detector_avg_speed_kmph_lag7', 0.14237583784918328),
#  ('prev_detector_density_vehpkm_lag7', 0.14125903503490456),
#  ('next_detector_density_vehpkm_lag5', 0.14112804147964209),
#  ('next_detector_avg_speed_kmph_lag8', 0.13998769597856242),
#  ('next_detector_density_vehpkm_lag6', 0.1397490289634682),
#  ('prev_detector_flow_vehph_lag2', 0.13756493137663606),
#  ('next_detector_density_vehpkm_lag2', 0.1367958229400239),
#  ('next_detector_density_vehpkm_lag7', 0.13458774087804048),
#  ('next_detector_avg_speed_kmph_lag10', 0.13380168834368522),
#  ('next_detector_density_vehpkm_lag8', 0.13221670071497282),
#  ('next_detector_delay_time_sec_lag10', 0.13218974381125115),
#  ('next_detector_section_travel_time_sec_lag10', 0.13206717223273934),
#  ('next_detector_delay_time_sec_lag8', 0.1313136384571374),
#  ('next_detector_section_travel_time_sec_lag8', 0.13123477639157244),
#  ('next_detector_section_travel_time_sec_lag9', 0.12951022492818698),
#  ('next_detector_delay_time_sec_lag9', 0.12898185171891363),
#  ('next_detector_density_vehpkm_lag10', 0.12764963430253307),
#  ('prev_detector_density_vehpkm_lag8', 0.12615244432987716),
#  ('density_vehpkm_lag10', 0.1260661834282173),
#  ('prev_detector_density_vehpkm_lag9', 0.12538506990450138),
#  ('prev_detector_flow_vehph_lag1', 0.12328970786488336),
#  ('next_detector_density_vehpkm_lag9', 0.12040386412030557),
#  ('flow_vehph_lag1', 0.11571929802794045),
#  ('prev_detector_flow_vehph_lag5', 0.10966360630452554),
#  ('prev_detector_density_vehpkm_lag10', 0.09723850220849961),
#  ('flow_vehph_lag2', 0.0929492943994763),
#  ('prev_detector_flow_vehph_lag7', 0.08848254798263522),
#  ('prev_detector_flow_vehph_lag6', 0.08753451842102766),
#  ('flow_vehph_lag3', 0.08580923659165762),
#  ('prev_detector_flow_vehph', 0.07869965652537125),
#  ('flow_vehph_lag7', 0.07204308804609383),
#  ('prev_detector_flow_vehph_lag10', 0.07136470541582352),
#  ('flow_vehph_lag4', 0.07036903479801637),
#  ('flow_vehph_lag6', 0.06786649460895156),
#  ('prev_detector_flow_vehph_lag8', 0.06651792064478279),
#  ('next_detector_flow_vehph', 0.06483632270251949),
#  ('next_detector_flow_vehph_lag1', 0.06367304524566997),
#  ('flow_vehph_lag8', 0.06216445211604693),
#  ('flow_vehph_lag5', 0.06193164111734539),
#  ('next_detector_flow_vehph_lag2', 0.06047559976721395),
#  ('prev_detector_flow_vehph_lag9', 0.06032053296982198),
#  ('next_detector_flow_vehph_lag5', 0.05710287431100802),
#  ('next_detector_flow_vehph_lag4', 0.05533282427299735),
#  ('next_detector_flow_vehph_lag3', 0.05326371610990144),
#  ('next_detector_flow_vehph_lag8', 0.05315149430758126),
#  ('next_detector_flow_vehph_lag7', 0.052089813784243155),
#  ('flow_vehph_lag9', 0.04853482873300585),
#  ('flow_vehph_lag10', 0.04847635294174246),
#  ('next_detector_flow_vehph_lag10', 0.047045886531681624),
#  ('next_detector_flow_vehph_lag6', 0.04678602361370032),
#  ('next_detector_flow_vehph_lag9', 0.04323951475794541),
#  ('distance_to_accident', 0.03342667696247448),
#  ('time_after_accident_started', 0.011452864907866012),
#  ('is_accident_timestamp', 0.005970480433907133)]

# %% [markdown]
# ## Calculate Feature~Target Correlation

# %% [markdown]
# ## Correlation Plot

# %%
sns.set_theme(style="white")

# Compute the correlation matrix
correlation_matrix = df_train[feature_columns+["target"]].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
#figure(num=None, figsize=(20, 12), dpi=80, facecolor="w", edgecolor="k")
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(100, 60))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlation_matrix, mask=mask, 
            cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
x_train_sample_extended = x_train_sample.copy()
x_train_sample_extended["target"] = y_train_sample

# %%
feature_correlation_information = x_train_sample_extended.corr()["target"][:-1]
correlation_descending_importance_index = np.argsort(feature_correlation_information.abs())[::-1] # Take absolute correlation
labeled_sorted_feature_correlation_informations = list(zip(feature_columns[correlation_descending_importance_index],feature_correlation_information[correlation_descending_importance_index]))

# %%
pprint.pprint(labeled_sorted_feature_correlation_informations)
# Out:
# [('delay_time_sec', 0.8317583239701359),
#  ('section_travel_time_sec', 0.8317583239701358),
#  ('delay_time_sec_lag1', 0.7233034308133626),
#  ('section_travel_time_sec_lag1', 0.7233034308133625),
#  ('section_travel_time_sec_lag3', 0.6879271253873855),
#  ('delay_time_sec_lag3', 0.6879271253873855),
#  ('section_travel_time_sec_lag4', 0.6817676740353644),
#  ('delay_time_sec_lag4', 0.6817676740353642),
#  ('delay_time_sec_lag5', 0.6791516096845567),
#  ('section_travel_time_sec_lag5', 0.6791516096845566),
#  ('delay_time_sec_lag2', 0.6773836771700158),
#  ('section_travel_time_sec_lag2', 0.6773836771700157),
#  ('next_detector_delay_time_sec_lag6', 0.6253425988876425),
#  ('next_detector_section_travel_time_sec_lag6', 0.625342598887642),
#  ('delay_time_sec_lag6', 0.6187852283681293),
#  ('section_travel_time_sec_lag6', 0.6187852283681291),
#  ('delay_time_sec_lag7', 0.6102088535215989),
#  ('section_travel_time_sec_lag7', 0.6102088535215988),
#  ('next_detector_section_travel_time_sec_lag5', 0.607583723301211),
#  ('next_detector_delay_time_sec_lag5', 0.6075837233012108),
#  ('density_vehpkm', 0.6037761581169897),
#  ('next_detector_delay_time_sec_lag7', 0.5871185225799472),
#  ('next_detector_section_travel_time_sec_lag7', 0.5871185225799471),
#  ('delay_time_sec_lag8', 0.576309363154907),
#  ('section_travel_time_sec_lag8', 0.5763093631549068),
#  ('density_vehpkm_lag1', 0.5748096320799799),
#  ('density_vehpkm_lag2', 0.5612115334743817),
#  ('next_detector_section_travel_time_sec_lag4', 0.5552295722940153),
#  ('next_detector_delay_time_sec_lag4', 0.555229572294015),
#  ('density_vehpkm_lag3', 0.5508929235386968),
#  ('section_travel_time_sec_lag9', 0.532450567446936),
#  ('delay_time_sec_lag9', 0.5324505674469359),
#  ('density_vehpkm_lag4', 0.532342852973363),
#  ('next_detector_delay_time_sec_lag8', 0.5319478525187891),
#  ('next_detector_section_travel_time_sec_lag8', 0.531947852518789),
#  ('next_detector_section_travel_time_sec_lag9', 0.5306346284656186),
#  ('next_detector_delay_time_sec_lag9', 0.5306346284656185),
#  ('density_vehpkm_lag5', 0.5215897983468977),
#  ('next_detector_delay_time_sec_lag10', 0.5038195535048412),
#  ('next_detector_section_travel_time_sec_lag10', 0.503819553504841),
#  ('density_vehpkm_lag6', 0.5036737387107746),
#  ('next_detector_delay_time_sec_lag2', 0.5001021028979865),
#  ('next_detector_section_travel_time_sec_lag2', 0.5001021028979864),
#  ('next_detector_delay_time_sec_lag3', 0.49838633755891354),
#  ('next_detector_section_travel_time_sec_lag3', 0.49838633755891343),
#  ('avg_speed_kmph', -0.4975947534564894),
#  ('density_vehpkm_lag7', 0.48871027357833047),
#  ('next_detector_delay_time_sec', 0.4795701214308525),
#  ('next_detector_section_travel_time_sec', 0.4795701214308525),
#  ('next_detector_section_travel_time_sec_lag1', 0.4752947668573122),
#  ('next_detector_delay_time_sec_lag1', 0.4752947668573121),
#  ('density_vehpkm_lag8', 0.47502546591369543),
#  ('avg_speed_kmph_lag1', -0.474282128393579),
#  ('delay_time_sec_lag10', 0.46220916314740856),
#  ('section_travel_time_sec_lag10', 0.46220916314740845),
#  ('avg_speed_kmph_lag2', -0.4583638977882247),
#  ('density_vehpkm_lag9', 0.45379573757476926),
#  ('avg_speed_kmph_lag3', -0.44551120438009034),
#  ('density_vehpkm_lag10', 0.4411579993454945),
#  ('avg_speed_kmph_lag4', -0.43463743791878806),
#  ('avg_speed_kmph_lag5', -0.42546614229112856),
#  ('prev_detector_section_travel_time_sec', 0.42227580956944966),
#  ('prev_detector_delay_time_sec', 0.4222758095694496),
#  ('avg_speed_kmph_lag6', -0.41437583307698383),
#  ('next_detector_density_vehpkm_lag5', 0.40671757752582205),
#  ('avg_speed_kmph_lag7', -0.4052234599286688),
#  ('prev_detector_section_travel_time_sec_lag1', 0.40410194255965154),
#  ('prev_detector_delay_time_sec_lag1', 0.40410194255965154),
#  ('next_detector_density_vehpkm_lag6', 0.4030677639389514),
#  ('avg_speed_kmph_lag8', -0.3952878097430993),
#  ('next_detector_density_vehpkm_lag4', 0.39179210172124374),
#  ('next_detector_density_vehpkm_lag7', 0.38955975662118786),
#  ('avg_speed_kmph_lag9', -0.38528483341235437),
#  ('next_detector_density_vehpkm_lag8', 0.38474643482401066),
#  ('next_detector_density_vehpkm_lag9', 0.379949462088458),
#  ('next_detector_density_vehpkm_lag10', 0.37903487137554187),
#  ('prev_detector_section_travel_time_sec_lag2', 0.37839524298000815),
#  ('prev_detector_delay_time_sec_lag2', 0.3783952429800078),
#  ('avg_speed_kmph_lag10', -0.3756429101173982),
#  ('next_detector_density_vehpkm_lag2', 0.3725740000992332),
#  ('next_detector_density_vehpkm_lag1', 0.37010535986791815),
#  ('next_detector_density_vehpkm_lag3', 0.3697168220332547),
#  ('next_detector_density_vehpkm', 0.36430734389046776),
#  ('prev_detector_density_vehpkm_lag1', 0.34276015872000176),
#  ('prev_detector_density_vehpkm', 0.34145396940980344),
#  ('prev_detector_density_vehpkm_lag2', 0.3397825389564651),
#  ('prev_detector_avg_speed_kmph_lag2', -0.33362587662996407),
#  ('prev_detector_avg_speed_kmph_lag1', -0.33069888032104144),
#  ('prev_detector_density_vehpkm_lag3', 0.32855907553615027),
#  ('prev_detector_avg_speed_kmph_lag3', -0.3270436257447284),
#  ('prev_detector_avg_speed_kmph', -0.3253614445197258),
#  ('prev_detector_density_vehpkm_lag4', 0.3162831934631293),
#  ('prev_detector_section_travel_time_sec_lag3', 0.3142953042978973),
#  ('prev_detector_delay_time_sec_lag3', 0.3142953042978972),
#  ('prev_detector_avg_speed_kmph_lag4', -0.31428688874557575),
#  ('prev_detector_section_travel_time_sec_lag5', 0.3046050334577608),
#  ('prev_detector_delay_time_sec_lag5', 0.30460503345776063),
#  ('prev_detector_section_travel_time_sec_lag4', 0.30428276106958885),
#  ('prev_detector_delay_time_sec_lag4', 0.3042827610695888),
#  ('next_detector_avg_speed_kmph_lag6', -0.30355162978467626),
#  ('next_detector_avg_speed_kmph_lag5', -0.3024252859559518),
#  ('next_detector_avg_speed_kmph_lag4', -0.30178008061787787),
#  ('prev_detector_delay_time_sec_lag7', 0.29954584103110743),
#  ('prev_detector_section_travel_time_sec_lag7', 0.29954584103110715),
#  ('prev_detector_density_vehpkm_lag5', 0.29919386016201627),
#  ('prev_detector_avg_speed_kmph_lag5', -0.2976554452725699),
#  ('next_detector_avg_speed_kmph_lag7', -0.2968234267947679),
#  ('next_detector_avg_speed_kmph_lag1', -0.29624767350328324),
#  ('prev_detector_delay_time_sec_lag6', 0.29521714401782995),
#  ('prev_detector_section_travel_time_sec_lag6', 0.29521714401782984),
#  ('next_detector_avg_speed_kmph_lag10', -0.2949093227325661),
#  ('next_detector_avg_speed_kmph_lag3', -0.2946078104703553),
#  ('next_detector_avg_speed_kmph_lag8', -0.2939489005941265),
#  ('next_detector_avg_speed_kmph_lag9', -0.2931782325394287),
#  ('next_detector_avg_speed_kmph_lag2', -0.2927719171810902),
#  ('next_detector_avg_speed_kmph', -0.29257074694088353),
#  ('prev_detector_section_travel_time_sec_lag8', 0.290924620829345),
#  ('prev_detector_delay_time_sec_lag8', 0.290924620829345),
#  ('prev_detector_density_vehpkm_lag6', 0.2885701253099321),
#  ('prev_detector_avg_speed_kmph_lag6', -0.28331077254522996),
#  ('prev_detector_section_travel_time_sec_lag10', 0.28302577080028696),
#  ('prev_detector_delay_time_sec_lag10', 0.2830257708002865),
#  ('prev_detector_section_travel_time_sec_lag9', 0.28047090805493013),
#  ('prev_detector_delay_time_sec_lag9', 0.28047090805493),
#  ('prev_detector_density_vehpkm_lag7', 0.27254644479553874),
#  ('prev_detector_avg_speed_kmph_lag7', -0.265715383611338),
#  ('prev_detector_avg_speed_kmph_lag8', -0.2538075793524606),
#  ('prev_detector_density_vehpkm_lag8', 0.2509275049375716),
#  ('prev_detector_avg_speed_kmph_lag9', -0.24683266069154247),
#  ('prev_detector_density_vehpkm_lag9', 0.2463475598113298),
#  ('prev_detector_density_vehpkm_lag10', 0.23479459260176683),
#  ('prev_detector_avg_speed_kmph_lag10', -0.22886311386195163),
#  ('flow_vehph', 0.17716839381351876),
#  ('flow_vehph_lag1', 0.16124106698070437),
#  ('flow_vehph_lag2', 0.15480170788450565),
#  ('flow_vehph_lag3', 0.1490339557805046),
#  ('flow_vehph_lag4', 0.14035801254526767),
#  ('flow_vehph_lag5', 0.13637249326788436),
#  ('flow_vehph_lag6', 0.13108579725225505),
#  ('flow_vehph_lag7', 0.12402462902807879),
#  ('flow_vehph_lag8', 0.11945623553345952),
#  ('prev_detector_flow_vehph_lag4', 0.11551019712604498),
#  ('flow_vehph_lag9', 0.11534711791001952),
#  ('prev_detector_flow_vehph_lag3', 0.11451503279803962),
#  ('flow_vehph_lag10', 0.11298450045620603),
#  ('prev_detector_flow_vehph_lag2', 0.1122859006517844),
#  ('prev_detector_flow_vehph_lag5', 0.10884526477144989),
#  ('prev_detector_flow_vehph_lag1', 0.10520516887099902),
#  ('prev_detector_flow_vehph_lag6', 0.09915200653428057),
#  ('prev_detector_flow_vehph', 0.08996564679826662),
#  ('prev_detector_flow_vehph_lag7', 0.08892266521810849),
#  ('next_detector_flow_vehph', 0.08315836173071695),
#  ('prev_detector_flow_vehph_lag9', 0.07915503259768768),
#  ('prev_detector_flow_vehph_lag8', 0.07827845795099299),
#  ('time_after_accident_started', 0.07732967451720028),
#  ('next_detector_flow_vehph_lag1', 0.07496687066232635),
#  ('next_detector_flow_vehph_lag5', 0.07469682748519473),
#  ('next_detector_flow_vehph_lag6', 0.07423524399919118),
#  ('next_detector_flow_vehph_lag2', 0.07286471755636602),
#  ('next_detector_flow_vehph_lag4', 0.07227230901350903),
#  ('prev_detector_flow_vehph_lag10', 0.069917365378138),
#  ('next_detector_flow_vehph_lag3', 0.0683038838183199),
#  ('next_detector_flow_vehph_lag8', 0.06615349841794498),
#  ('next_detector_flow_vehph_lag9', 0.06501142142366283),
#  ('next_detector_flow_vehph_lag7', 0.06405091392665929),
#  ('next_detector_flow_vehph_lag10', 0.06108413934410595),
#  ('is_accident_timestamp', 0.0517265218206991),
#  ('distance_to_accident', -0.05172300661161123)]

# %% [markdown]
# ## Serialize

# %%
mutual_information_feature_order_df = pd.DataFrame(labeled_sorted_feature_mutual_informations)
mutual_information_feature_order_df.columns = ["feature","value"]
mutual_information_feature_order_df["order"] = mutual_information_feature_order_df.index + 1


correlation_feature_order_df = pd.DataFrame(labeled_sorted_feature_correlation_informations)
correlation_feature_order_df.columns = ["feature","value"]
correlation_feature_order_df["order"] = correlation_feature_order_df.index + 1


mutual_information_feature_order_df.to_csv(os.path.join(ROOT_DIRECTORY,"data/thesis_data/mutual_information_feature_orders.csv"),index=False)
correlation_feature_order_df.to_csv(os.path.join(ROOT_DIRECTORY,"data/thesis_data/correlation_feature_orders.csv"),index=False)
